# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

d = scipy.io.loadmat('pop_firing_rate.mat',squeeze_me=True)

rho_data = d['rho_data']

rho_data
# Out:
# array([[0.091  , 0.104  , 0.083  , ..., 0.099  , 0.106  , 0.092  ],
#        [0.11   , 0.16   , 0.09   , ..., 0.08   , 0.12   , 0.13   ],
#        [0.09588, 0.09513, 0.09564, ..., 0.09378, 0.09698, 0.09565],
#        [0.1    , 0.3    , 0.     , ..., 0.2    , 0.2    , 0.1    ],
#        [0.0962 , 0.0972 , 0.0974 , ..., 0.0892 , 0.0957 , 0.0974 ]])

# %% [markdown]
# ### 1. Each entry `rho_data[k]` is a firing rate of a given population of $N_k$ neurons. The neurons in each population can be considered to emit __Poisson spike trains__. Can you tell:
#
# ### a) which firing rate (`1` to `5`) corresponds to the population with the largest number of neurons?
#
# ### b) which corresponds to the population with the smallest number of neurons?
#
# ### Use a __suitable statistical measure__ to support your claim.
